# %%
import pandas as pd
import numpy as np
import kaplanmeier as km
import matplotlib.pyplot as plt
from lifelines import KaplanMeierFitter
import seaborn as sns

# %%
samples = pd.read_csv('ns.csv')

print(len(samples))
# Out:
# 2560

# %%
samples.head()
# Out:
#                         _id              cohorts.0.id  \
# 0  5bab56c2727983b2e00abf78  pgxcohort-2021progenetix
# 1  5bab56c3727983b2e00ac462  pgxcohort-2021progenetix
# 2  5bab56c3727983b2e00ac463  pgxcohort-2021progenetix
# 3  5bab56c3727983b2e00ac464  pgxcohort-2021progenetix
# 4  5bab56c3727983b2e00ac465  pgxcohort-2021progenetix
#
#                      cohorts.0.label dataUseConditions.id  \
# 0  Version at Progenetix Update 2021          DUO:0000004
# 1  Version at Progenetix Update 2021          DUO:0000004
# 2  Version at Progenetix Update 2021          DUO:0000004
# 3  Version at Progenetix Update 2021          DUO:0000004
# 4  Version at Progenetix Update 2021          DUO:0000004
#
#   dataUseConditions.label                    description  \
# 0          no restriction     Ependymoma [4th ventricle]
# 1          no restriction     ependymoma [Left cerebral]
# 2          no restriction  ependymoma [fourth ventricle]
# 3          no restriction  ependymoma [fourth ventricle]
# 4          no restriction  ependymoma [fourth ventricle]
#
#   histologicalDiagnosis.id histologicalDiagnosis.label icdoMorphology.id  \
# 0               NCIT:C3017                  Ependymoma       icdom-93913
# 1               NCIT:C3017                  Ependymoma       icdom-93913
# 2               NCIT:C3017                  Ependymoma       icdom-93913
# 3               NCIT:C3017                  Ependymoma       icdom-93913
# 4               NCIT:C3017                  Ependymoma       icdom-93913
#
#   icdoMorphology.label  ... provenance.populations.0.type.label  \
# 0      Ependymoma, NOS  ...                                 NaN
# 1      Ependymoma, NOS  ...                                 NaN
# 2      Ependymoma, NOS  ...                                 NaN
# 3      Ependymoma, NOS  ...                                 NaN
# 4      Ependymoma, NOS  ...                                 NaN
#
#   provenance.populations.1.confidence provenance.populations.1.description  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   provenance.populations.1.type.id provenance.populations.1.type.label  \
# 0                              NaN                                 NaN
# 1                              NaN                                 NaN
# 2                              NaN                                 NaN
# 3                              NaN                                 NaN
# 4                              NaN                                 NaN
#
#   info.cellLine  info.samplesource  info.seer  projectId  sex
# 0           NaN                NaN        NaN        NaN    F
# 1           NaN                NaN        NaN        NaN    M
# 2           NaN                NaN        NaN        NaN    F
# 3           NaN                NaN        NaN        NaN    M
# 4           NaN                NaN        NaN        NaN    F
#
# [5 rows x 104 columns]

# %%
for col in samples.columns:
    print(col)
# Out:
# _id
# cohorts.0.id
# cohorts.0.label
# dataUseConditions.id
# dataUseConditions.label
# description
# histologicalDiagnosis.id
# histologicalDiagnosis.label
# icdoMorphology.id
# icdoMorphology.label
# icdoTopography.id
# icdoTopography.label
# id
# individualAgeAtCollection
# individualId
# info.callsetIds.0
# info.cnvstatistics.cnvcoverage
# info.cnvstatistics.cnvfraction
# info.cnvstatistics.delcoverage
# info.cnvstatistics.delfraction
# info.cnvstatistics.dupcoverage
# info.cnvstatistics.dupfraction
# info.legacyId.0
# pathologicalStage
# provenance.geoLocation.geometry.coordinates.0
# provenance.geoLocation.geometry.coordinates.1
# provenance.geoLocation.geometry.type
# provenance.geoLocation.properties.ISO3166alpha3
# provenance.geoLocation.properties.city
# provenance.geoLocation.properties.country
# provenance.geoLocation.properties.label
# provenance.geoLocation.properties.latitude
# provenance.geoLocation.properties.longitude
# provenance.geoLocation.properties.precision
# provenance.geoLocation.type
# provenance.material.id
# provenance.material.label
# sampledTissue.id
# sampledTissue.label
# tumorGrade
# updated
# externalReferences.0.id
# externalReferences.0.label
# info.death
# info.followupMonths
# tumorGrade.id
# tumorGrade.label
# info.tnm
# pathologicalStage.id
# pathologicalStage.label
# pathologicalTnmFindings.0.id
# pathologicalTnmFindings.0.label
# pathologicalTnmFindings.1.id
# pathologicalTnmFindings.1.label
# cohorts.1.id
# cohorts.1.label
# info.legacyId.1
# info.cnvstatistics
# info.callsetIds.1
# externalReferences.1.id
# externalReferences.1.label
# externalReferences.0.description
# histologicalDiagnosis.description
# icdoMorphology.description
# icdoTopography.description
# info.grade
# info.histone
# info.location
# info.methylation
# info.mgmt
# info.months
# info.provenance
# info.sampling
# info.status
# externalReferences.1.description
# externalReferences.2.description
# externalReferences.2.id
# externalReferences.2.label
# cohorts.2.id
# cohorts.2.label
# info.tumorStage
# cohorts.3.id
# cohorts.3.label
# cohorts.4.id
# cohorts.4.label
# externalReferences.3.description
# externalReferences.3.id
# externalReferences.3.label
# externalReferences.4.description
# externalReferences.4.id
# externalReferences.4.label
# provenance.populations.0.confidence
# provenance.populations.0.description
# provenance.populations.0.type.id
# provenance.populations.0.type.label
# provenance.populations.1.confidence
# provenance.populations.1.description
# provenance.populations.1.type.id
# provenance.populations.1.type.label
# info.cellLine
# info.samplesource
# info.seer
# projectId
# sex

# %%
samples[samples.isna().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [_id, cohorts.0.id, cohorts.0.label, dataUseConditions.id, dataUseConditions.label, description, histologicalDiagnosis.id, histologicalDiagnosis.label, icdoMorphology.id, icdoMorphology.label, icdoTopography.id, icdoTopography.label, id, individualAgeAtCollection, individualId, info.callsetIds.0, info.cnvstatistics.cnvcoverage, info.cnvstatistics.cnvfraction, info.cnvstatistics.delcoverage, info.cnvstatistics.delfraction, info.cnvstatistics.dupcoverage, info.cnvstatistics.dupfraction, info.legacyId.0, pathologicalStage, provenance.geoLocation.geometry.coordinates.0, provenance.geoLocation.geometry.coordinates.1, provenance.geoLocation.geometry.type, provenance.geoLocation.properties.ISO3166alpha3, provenance.geoLocation.properties.city, provenance.geoLocation.properties.country, provenance.geoLocation.properties.label, provenance.geoLocation.properties.latitude, provenance.geoLocation.properties.longitude, provenance.geoLocation.properties.precision, provenance.geoLocation.type, provenance.material.id, provenance.material.label, sampledTissue.id, sampledTissue.label, tumorGrade, updated, externalReferences.0.id, externalReferences.0.label, info.death, info.followupMonths, tumorGrade.id, tumorGrade.label, info.tnm, pathologicalStage.id, pathologicalStage.label, pathologicalTnmFindings.0.id, pathologicalTnmFindings.0.label, pathologicalTnmFindings.1.id, pathologicalTnmFindings.1.label, cohorts.1.id, cohorts.1.label, info.legacyId.1, info.cnvstatistics, info.callsetIds.1, externalReferences.1.id, externalReferences.1.label, externalReferences.0.description, histologicalDiagnosis.description, icdoMorphology.description, icdoTopography.description, info.grade, info.histone, info.location, info.methylation, info.mgmt, info.months, info.provenance, info.sampling, info.status, externalReferences.1.description, externalReferences.2.description, externalReferences.2.id, externalReferences.2.label, cohorts.2.id, cohorts.2.label, info.tumorStage, cohorts.3.id, cohorts.3.label, cohorts.4.id, cohorts.4.label, externalReferences.3.description, externalReferences.3.id, externalReferences.3.label, externalReferences.4.description, externalReferences.4.id, externalReferences.4.label, provenance.populations.0.confidence, provenance.populations.0.description, provenance.populations.0.type.id, provenance.populations.0.type.label, provenance.populations.1.confidence, provenance.populations.1.description, provenance.populations.1.type.id, provenance.populations.1.type.label, info.cellLine, ...]
# Index: []
#
# [0 rows x 104 columns]

# %%
cdkn2a = pd.read_csv('cdkn2a_biosample.tsv', sep='\t')
erbb2 = pd.read_csv('erbb2_biosample.tsv', sep='\t')
myc = pd.read_csv('myc_biosample.tsv', sep='\t')
tp53 = pd.read_csv('tp53_biosample.tsv', sep='\t')

# %%
tp53.head()
# Out:
#      biosample_id  group_id  group_label    individual_id     callset_ids  \
# 0  pgxbs-kftva59y       NaN          NaN  pgxind-kftx25eh  pgxcs-kftvldsu
# 1  pgxbs-kftva5a2       NaN          NaN  pgxind-kftx25em  pgxcs-kftvldtu
# 2  pgxbs-kftva5a4       NaN          NaN  pgxind-kftx25en  pgxcs-kftvldud
# 3  pgxbs-kftva5ac       NaN          NaN  pgxind-kftx25ex  pgxcs-kftvldwr
# 4  pgxbs-kftva5ah       NaN          NaN  pgxind-kftx25f3  pgxcs-kftvldy7
#
#   external_references_id___PMID  external_references_label___PMID  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                           NaN                               NaN
# 4                           NaN                               NaN
#
#   external_references_id___arrayexpress  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   external_references_label___arrayexpress  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   external_references_id___cbioportal  ...  geoprov_long_lat cnv_fraction  \
# 0                                 NaN  ...       30.7::36.91          NaN
# 1                                 NaN  ...       30.7::36.91          NaN
# 2                                 NaN  ...       30.7::36.91          NaN
# 3                                 NaN  ...       30.7::36.91          NaN
# 4                                 NaN  ...       30.7::36.91          NaN
#
#   cnv_del_fraction cnv_dup_fraction cell_line experiment_id series_id  \
# 0              NaN              NaN       NaN           NaN       NaN
# 1              NaN              NaN       NaN           NaN       NaN
# 2              NaN              NaN       NaN           NaN       NaN
# 3              NaN              NaN       NaN           NaN       NaN
# 4              NaN              NaN       NaN           NaN       NaN
#
#   platform_id cell_line_id cell_line_label
# 0         NaN          NaN             NaN
# 1         NaN          NaN             NaN
# 2         NaN          NaN             NaN
# 3         NaN          NaN             NaN
# 4         NaN          NaN             NaN
#
# [5 rows x 49 columns]

# %%
for col in tp53.columns:
    print(col)
# Out:
# biosample_id
# group_id
# group_label
# individual_id
# callset_ids
# external_references_id___PMID
# external_references_label___PMID
# external_references_id___arrayexpress
# external_references_label___arrayexpress
# external_references_id___cbioportal
# external_references_label___cbioportal
# external_references_id___cellosaurus
# external_references_label___cellosaurus
# legacy_ids
# notes
# histological_diagnosis_id
# histological_diagnosis_label
# icdo_morphology_id
# icdo_morphology_label
# icdo_topography_id
# icdo_topography_label
# pathological_stage_id
# pathological_stage_label
# biosample_status_id
# biosample_status_label
# sampled_tissue_id
# sampled_tissue_label
# tnm
# stage
# grade
# age_iso
# sex_id
# sex_label
# followup_state_id
# followup_state_label
# followup_time
# geoprov_city
# geoprov_country
# geoprov_iso_alpha3
# geoprov_long_lat
# cnv_fraction
# cnv_del_fraction
# cnv_dup_fraction
# cell_line
# experiment_id
# series_id
# platform_id
# cell_line_id
# cell_line_label

# %%
tp53[tp53.isna().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [biosample_id, group_id, group_label, individual_id, callset_ids, external_references_id___PMID, external_references_label___PMID, external_references_id___arrayexpress, external_references_label___arrayexpress, external_references_id___cbioportal, external_references_label___cbioportal, external_references_id___cellosaurus, external_references_label___cellosaurus, legacy_ids, notes, histological_diagnosis_id, histological_diagnosis_label, icdo_morphology_id, icdo_morphology_label, icdo_topography_id, icdo_topography_label, pathological_stage_id, pathological_stage_label, biosample_status_id, biosample_status_label, sampled_tissue_id, sampled_tissue_label, tnm, stage, grade, age_iso, sex_id, sex_label, followup_state_id, followup_state_label, followup_time, geoprov_city, geoprov_country, geoprov_iso_alpha3, geoprov_long_lat, cnv_fraction, cnv_del_fraction, cnv_dup_fraction, cell_line, experiment_id, series_id, platform_id, cell_line_id, cell_line_label]
# Index: []
#
# [0 rows x 49 columns]

# %%
myc.head()
# Out:
#      biosample_id  group_id  group_label    individual_id     callset_ids  \
# 0  pgxbs-kftva5a1       NaN          NaN  pgxind-kftx25ek  pgxcs-kftvldtc
# 1  pgxbs-kftva5ab       NaN          NaN  pgxind-kftx25ev  pgxcs-kftvldwa
# 2  pgxbs-kftva5de       NaN          NaN  pgxind-kftx25io  pgxcs-kftvlet0
# 3  pgxbs-kftva5dq       NaN          NaN  pgxind-kftx25j3  pgxcs-kftvlewg
# 4  pgxbs-kftva5e9       NaN          NaN  pgxind-kftx25jr  pgxcs-kftvlf4a
#
#   external_references_id___PMID  external_references_label___PMID  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
# 2                  PMID:9950502                               NaN
# 3                  PMID:9950502                               NaN
# 4                  PMID:9950502                               NaN
#
#   external_references_id___arrayexpress  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   external_references_label___arrayexpress  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   external_references_id___cbioportal  ...  geoprov_long_lat cnv_fraction  \
# 0                                 NaN  ...       30.7::36.91          NaN
# 1                                 NaN  ...       30.7::36.91          NaN
# 2                                 NaN  ...    -122.42::37.77          NaN
# 3                                 NaN  ...    -122.42::37.77          NaN
# 4                                 NaN  ...    -122.42::37.77          NaN
#
#   cnv_del_fraction cnv_dup_fraction cell_line experiment_id series_id  \
# 0              NaN              NaN       NaN           NaN       NaN
# 1              NaN              NaN       NaN           NaN       NaN
# 2              NaN              NaN       NaN           NaN       NaN
# 3              NaN              NaN       NaN           NaN       NaN
# 4              NaN              NaN       NaN           NaN       NaN
#
#   platform_id cell_line_id cell_line_label
# 0         NaN          NaN             NaN
# 1         NaN          NaN             NaN
# 2         NaN          NaN             NaN
# 3         NaN          NaN             NaN
# 4         NaN          NaN             NaN
#
# [5 rows x 49 columns]

# %%
myc[myc.isna().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [biosample_id, group_id, group_label, individual_id, callset_ids, external_references_id___PMID, external_references_label___PMID, external_references_id___arrayexpress, external_references_label___arrayexpress, external_references_id___cbioportal, external_references_label___cbioportal, external_references_id___cellosaurus, external_references_label___cellosaurus, legacy_ids, notes, histological_diagnosis_id, histological_diagnosis_label, icdo_morphology_id, icdo_morphology_label, icdo_topography_id, icdo_topography_label, pathological_stage_id, pathological_stage_label, biosample_status_id, biosample_status_label, sampled_tissue_id, sampled_tissue_label, tnm, stage, grade, age_iso, sex_id, sex_label, followup_state_id, followup_state_label, followup_time, geoprov_city, geoprov_country, geoprov_iso_alpha3, geoprov_long_lat, cnv_fraction, cnv_del_fraction, cnv_dup_fraction, cell_line, experiment_id, series_id, platform_id, cell_line_id, cell_line_label]
# Index: []
#
# [0 rows x 49 columns]

# %%
tumor_ids = list(samples['individualId'])
tumor_ids[0:10]
# Out:
# ['pgxind-kftx2ejj',
#  'pgxind-kftx2gil',
#  'pgxind-kftx2gin',
#  'pgxind-kftx2gip',
#  'pgxind-kftx2gir',
#  'pgxind-kftx2git',
#  'pgxind-kftx2giv',
#  'pgxind-kftx2giz',
#  'pgxind-kftx2gj1',
#  'pgxind-kftx2gj3']

# %%
cdkn2a_ids = list(cdkn2a['individual_id'])
erbb2_ids = list(erbb2['individual_id'])
myc_ids = list(myc['individual_id'])
tp53_ids = list(tp53['individual_id'])

# %%
cdkn2a_ids[0:10]
# Out:
# ['pgxind-kftx266l',
#  'pgxind-kftx266t',
#  'pgxind-kftx266v',
#  'pgxind-kftx266z',
#  'pgxind-kftx2671',
#  'pgxind-kftx2675',
#  'pgxind-kftx26j0',
#  'pgxind-kftx274e',
#  'pgxind-kftx274m',
#  'pgxind-kftx274q']

# %%
# Create a new DataFrame with selected columns
columns_to_select = [
    'individualId', 'info.death', 'info.followupMonths', 'sex',
    'histologicalDiagnosis.id', 'histologicalDiagnosis.label',
    'info.cnvstatistics.cnvfraction', 'info.cnvstatistics.cnvcoverage',
    'provenance.geoLocation.properties.ISO3166alpha3', 'individualAgeAtCollection'
]
final_data = samples[columns_to_select].copy()
final_data
# Out:
#          individualId  info.death  info.followupMonths sex  \
# 0     pgxind-kftx2ejj           0                 32.0   F
# 1     pgxind-kftx2gil           0                 24.0   M
# 2     pgxind-kftx2gin           0                 10.0   F
# 3     pgxind-kftx2gip           0                  3.0   M
# 4     pgxind-kftx2gir           0                 19.0   F
# ...               ...         ...                  ...  ..
# 2555  pgxind-kftx2btr           1                 10.0   F
# 2556  pgxind-kftx2btt           1                 20.0   M
# 2557  pgxind-kftx3ajf           1                  5.0   F
# 2558  pgxind-kftx3ajh           1                 33.0   M
# 2559  pgxind-kftx3ajj           1                 13.0   F
#
#      histologicalDiagnosis.id histologicalDiagnosis.label  \
# 0                  NCIT:C3017                  Ependymoma
# 1                  NCIT:C3017                  Ependymoma
# 2                  NCIT:C3017                  Ependymoma
# 3                  NCIT:C3017                  Ependymoma
# 4                  NCIT:C3017                  Ependymoma
# ...                       ...                         ...
# 2555               NCIT:C9344               Pineoblastoma
# 2556               NCIT:C9344               Pineoblastoma
# 2557               NCIT:C9344               Pineoblastoma
# 2558               NCIT:C9344               Pineoblastoma
# 2559               NCIT:C9344               Pineoblastoma
#
#       info.cnvstatistics.cnvfraction  info.cnvstatistics.cnvcoverage  \
# 0                              0.076                    2.186174e+08
# 1                              0.000                    0.000000e+00
# 2                              0.272                    7.832260e+08
# 3                              0.765                    2.200655e+09
# 4                              0.667                    1.916798e+09
# ...                              ...                             ...
# 2555                           0.134                    3.857168e+08
# 2556                           0.086                    2.468712e+08
# 2557                           0.127                    3.640158e+08
# 2558                           0.130                    3.723952e+08
# 2559                           0.044                    1.255963e+08
#
#      provenance.geoLocation.properties.ISO3166alpha3 individualAgeAtCollection
# 0                                                PRT                       P1Y
# 1                                                FRA                       P5Y
# 2                                                FRA                      P33Y
# 3                                                FRA                      P17Y
# 4                                                FRA                      P32Y
# ...                                              ...                       ...
# 2555                                             GBR                       P1Y
# 2556                                             GBR                       P1Y
# 2557                                             DEU                      P46Y
# 2558                                             DEU                       P1Y
# 2559                                             DEU                      P61Y
#
# [2560 rows x 10 columns]

# %%
# Initialize 'cdkn2a', 'erbb2', 'myc', 'tp53', and 'other' columns with zeros
final_data['cdkn2a'] = 0
final_data['erbb2'] = 0
final_data['myc'] = 0
final_data['tp53'] = 0
final_data['other'] = 0

# Use boolean indexing to set values in the 'cdkn2a', 'erbb2', 'myc', 'tp53' columns
final_data.loc[final_data['individualId'].isin(cdkn2a['individual_id']), 'cdkn2a'] = 1
final_data.loc[final_data['individualId'].isin(erbb2['individual_id']), 'erbb2'] = 1
final_data.loc[final_data['individualId'].isin(myc['individual_id']), 'myc'] = 1
final_data.loc[final_data['individualId'].isin(tp53['individual_id']), 'tp53'] = 1

# Calculate the 'other' column based on the absence of 'cdkn2a', 'erbb2', 'myc', and 'tp53'
final_data['other'] = 1 - (final_data['cdkn2a'] | final_data['erbb2'] | final_data['myc'] | final_data['tp53'])

final_data
# Out:
#          individualId  info.death  info.followupMonths sex  \
# 0     pgxind-kftx2ejj           0                 32.0   F
# 1     pgxind-kftx2gil           0                 24.0   M
# 2     pgxind-kftx2gin           0                 10.0   F
# 3     pgxind-kftx2gip           0                  3.0   M
# 4     pgxind-kftx2gir           0                 19.0   F
# ...               ...         ...                  ...  ..
# 2555  pgxind-kftx2btr           1                 10.0   F
# 2556  pgxind-kftx2btt           1                 20.0   M
# 2557  pgxind-kftx3ajf           1                  5.0   F
# 2558  pgxind-kftx3ajh           1                 33.0   M
# 2559  pgxind-kftx3ajj           1                 13.0   F
#
#      histologicalDiagnosis.id histologicalDiagnosis.label  \
# 0                  NCIT:C3017                  Ependymoma
# 1                  NCIT:C3017                  Ependymoma
# 2                  NCIT:C3017                  Ependymoma
# 3                  NCIT:C3017                  Ependymoma
# 4                  NCIT:C3017                  Ependymoma
# ...                       ...                         ...
# 2555               NCIT:C9344               Pineoblastoma
# 2556               NCIT:C9344               Pineoblastoma
# 2557               NCIT:C9344               Pineoblastoma
# 2558               NCIT:C9344               Pineoblastoma
# 2559               NCIT:C9344               Pineoblastoma
#
#       info.cnvstatistics.cnvfraction  info.cnvstatistics.cnvcoverage  \
# 0                              0.076                    2.186174e+08
# 1                              0.000                    0.000000e+00
# 2                              0.272                    7.832260e+08
# 3                              0.765                    2.200655e+09
# 4                              0.667                    1.916798e+09
# ...                              ...                             ...
# 2555                           0.134                    3.857168e+08
# 2556                           0.086                    2.468712e+08
# 2557                           0.127                    3.640158e+08
# 2558                           0.130                    3.723952e+08
# 2559                           0.044                    1.255963e+08
#
#      provenance.geoLocation.properties.ISO3166alpha3  \
# 0                                                PRT
# 1                                                FRA
# 2                                                FRA
# 3                                                FRA
# 4                                                FRA
# ...                                              ...
# 2555                                             GBR
# 2556                                             GBR
# 2557                                             DEU
# 2558                                             DEU
# 2559                                             DEU
#
#      individualAgeAtCollection  cdkn2a  erbb2  myc  tp53  other
# 0                          P1Y       1      0    0     0      0
# 1                          P5Y       0      0    0     0      1
# 2                         P33Y       0      0    0     0      1
# 3                         P17Y       0      0    0     0      1
# 4                         P32Y       0      0    1     1      0
# ...                        ...     ...    ...  ...   ...    ...
# 2555                       P1Y       0      0    0     0      1
# 2556                       P1Y       0      0    0     0      1
# 2557                      P46Y       1      0    0     0      0
# 2558                       P1Y       0      0    0     0      1
# 2559                      P61Y       0      0    0     0      1
#
# [2560 rows x 15 columns]

# %%
final_data.to_csv('ns_final.csv', index=False)
