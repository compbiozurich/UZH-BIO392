# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/serenagalli/Dropbox/Computational_Science/2023_HS/Bioinformatics of Sequence Variation/tasks/survival/lymphoma.csv', sep=',')
df
# Out:
#                           _id              cohorts.0.id  \
# 0    5bab56c2727983b2e00abd59  pgxcohort-2021progenetix
# 1    5bab56c2727983b2e00abd5b  pgxcohort-2021progenetix
# 2    5bab56c1727983b2e00ab69c  pgxcohort-2021progenetix
# 3    5bab56c1727983b2e00ab852  pgxcohort-2021progenetix
# 4    5c86623709d374f2dc3e1a2c        pgxcohort-arraymap
# ..                        ...                       ...
# 921  5bab56c9727983b2e00af11c  pgxcohort-2021progenetix
# 922  5bab56c9727983b2e00af11d  pgxcohort-2021progenetix
# 923  5bab56c9727983b2e00af11e  pgxcohort-2021progenetix
# 924  5bab56c9727983b2e00af11f  pgxcohort-2021progenetix
# 925  5bab56c9727983b2e00af121  pgxcohort-2021progenetix
#
#                        cohorts.0.label dataUseConditions.id  \
# 0    Version at Progenetix Update 2021          DUO:0000004
# 1    Version at Progenetix Update 2021          DUO:0000004
# 2    Version at Progenetix Update 2021          DUO:0000004
# ...

# %%
df_categories = df['icdoMorphology.label'].value_counts()

# %%
df_categories
# Out:
# icdoMorphology.label
# Malignant lymphoma, large B-cell, diffuse, NOS                    378
# Mantle cell lymphoma                                              125
# B-cell chronic lymphocytic leukemia/small lymphocytic lymphoma     89
# Precursor cell lymphoblastic leukemia, NOS                         87
# Splenic marginal zone B-cell lymphoma                              42
# Mature T-cell lymphoma, NOS                                        34
# Mycosis Fungoides                                                  30
# Anaplastic large cell lymphoma, cutaneous type                     29
# Acute myeloid leukemia, NOS                                        21
# Anaplastic large cell lymphoma, T cell and Null cell type          18
# Acute myeloid leukemia with maturation                             11
# Follicular lymphoma, NOS                                           11
# Primary cutaneous CD30+ T-cell lymphoproliferative disorder        11
# ...

# %%
df_tp53 = pd.read_csv('/Users/serenagalli/Dropbox/Computational_Science/2023_HS/Bioinformatics of Sequence Variation/tasks/survival/biosamples_TP53_deletion', sep='\t')
df_tp53
# Out:
#         biosample_id  group_id  group_label    individual_id     callset_ids  \
# 0     pgxbs-kftva5am       NaN          NaN  pgxind-kftx25fa  pgxcs-kftvldzm
# 1     pgxbs-kftva5au       NaN          NaN  pgxind-kftx25fk  pgxcs-kftvle20
# 2     pgxbs-kftva5b3       NaN          NaN  pgxind-kftx25fu  pgxcs-kftvle4d
# 3     pgxbs-kftva5be       NaN          NaN  pgxind-kftx25g8  pgxcs-kftvle7p
# 4     pgxbs-kftva5c3       NaN          NaN  pgxind-kftx25h3  pgxcs-kftvleew
# ...              ...       ...          ...              ...             ...
# 2362  pgxbs-l08ailus       NaN          NaN  pgxind-l08ailus             NaN
# 2363  pgxbs-l08ailyf       NaN          NaN  pgxind-l08ailyf             NaN
# 2364  pgxbs-l08ainhb       NaN          NaN  pgxind-l08ainhb             NaN
# 2365  pgxbs-l08ainis       NaN          NaN  pgxind-l08ainis             NaN
# 2366  pgxbs-l08ainmu       NaN          NaN  pgxind-l08ainmu             NaN
#
# ...
