# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


mycgain = "/Users/pfreita/Downloads/MYCgains"
mycdelet = "/Users/pfreita/Downloads/MYCdel"
survival = "/Users/pfreita/Downloads/lymphoma.csv"

## read the files into dataframes

df = pd.read_csv(survival)
df_gain = pd.read_csv(mycgain, delimiter= "\t")
df_del = pd.read_csv(mycdelet, delimiter= "\t")

# %%
columns = ["id", 'description', 'histologicalDiagnosis.id',
       'histologicalDiagnosis.label', 'icdoMorphology.id', 'info.death', 'info.followupMonths', "sex", 'ageAtCollection.age','sampledTissue.label']
df_small = df[columns]

# %%
## a list with all the id's that are in the provided csv file. to compare them with progenetix data
survival_data = list(df.id)

# %%
list_gain = list(df_gain.biosample_id)
list_del = list(df_del.biosample_id)

# %%
## add column to survival dataframe regarding the CNV status (deletion or gain or none) 
df_small["MYC"] = "Normal"
df_small.loc[df_small["id"].isin(list_gain), "MYC"] = "gain"
df_small.loc[df_small["id"].isin(list_del), "MYC"] = "del"
# Out:
# /var/folders/46/phzjr95j0rl1mn0t6q221fshhtt3y7/T/ipykernel_7159/2817618521.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small["MYC"] = "Normal"

# %%
df_small["MYC"].value_counts()
# Out:
# MYC
# Normal    820
# gain       98
# del         8
# Name: count, dtype: int64

# %%
df_small
# Out:
#                  id                                        description  \
# 0    pgxbs-kftvgmrz  refractory cytopenia with multilineage dysplas...
# 1    pgxbs-kftvgms2           acute myeloid leukemia [erythroleukemia]
# 2    pgxbs-kftvgklf               acute panmyelosis with myelofibrosis
# 3    pgxbs-kftvgl5c                             Acute myeloid leukemia
# 4    pgxbs-kftviwvv                             Acute myeloid leukemia
# ..              ...                                                ...
# 921  pgxbs-kftvh3pq          Diffuse large B-cell lymphoma [cutaneous]
# 922  pgxbs-kftvh3ps          Diffuse large B-cell lymphoma [cutaneous]
# 923  pgxbs-kftvh3pu          Diffuse large B-cell lymphoma [cutaneous]
# 924  pgxbs-kftvh3pv          Diffuse large B-cell lymphoma [cutaneous]
# 925  pgxbs-kftvh3py          Diffuse large B-cell lymphoma [cutaneous]
#
#     histologicalDiagnosis.id                     histologicalDiagnosis.label  \
# ...

# %%
## all the samples which have deletions in MYC gene

# dele = df_del[df_del["biosample_id"].isin(survival_data)]

## all the samples which have gains in MYC gene
# gain = df_gain[df_gain["biosample_id"].isin(survival_data)]

## shows which types of cancers are represented in numeric values in the gain data
# gain["icdo_morphology_label"].value_counts()

## shows which types of cancers are represented in numeric values in the deletion data

# dele["icdo_morphology_label"].value_counts()
